# %%
import os
import re
import sys

#import assets.parse_html as parse_html

webpage_html_files_path = re.sub(r'\\ ', ' ',
                                 '/content/drive/My Drive/Website Copies for testing nltk htmlcorpusmaker as per Text Analysis With Python/PSYCHOLOGY TODAY ARTICLE TEXT FOR NLP CATEGORIZATION AND RELATIONSHIP PROJECT/psychology today/conditions/')
output_text_files_path = "/content/drive/My Drive/Psychology Today Fiverr Coding Results - Text extraction from HTML/Output from Colab/"

exclude_nonparagraph_nonheading_text = True


# Read html files, return in list
def import_html_files():
    sources = []
    file_names = [f for f in os.listdir(webpage_html_files_path) if
                  os.path.isfile(os.path.join(webpage_html_files_path, f))]
    for file_name in file_names:
        sources.append([file_name, file_name[0:file_name.find('.')],
                        open(webpage_html_files_path + file_name, "rb").read().decode(sys.stdin.encoding,
                                                                                      errors='replace')])
    return sources


def main():
    sources = []
    sources = import_html_files()
    count = 0
    txt = ''
    for url, file_name, source in sources:
        # Tranquilize html and build text file
        try:
            txt = build_txt(source, url, exclude_nonparagraph_nonheading_text)
            print(txt)
        except:
            pass

        out_file = open(output_text_files_path + file_name + ".txt", "wb")
        out_file.write(txt['text'].encode(sys.stdout.encoding, errors='replace'))
        count += 1

# %%
main()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-263240bbee7e> in <module>()
# ----> 1 main()
#
# <ipython-input-21-baf348fb3394> in main()
#      38
#      39         out_file = open(output_text_files_path + file_name + ".txt", "wb")
# ---> 40         out_file.write(txt['text'].encode(sys.stdout.encoding, errors='replace'))
#      41         count += 1
#      42
#
# TypeError: string indices must be integers
